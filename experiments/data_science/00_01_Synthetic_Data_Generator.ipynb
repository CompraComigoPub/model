# %% [markdown]
# # Synthetic Data Generator

# %% [markdown]
# Generates synthetic time series data .

# %%
import sys
sys.path.append('../..')

from model_compra_comigo.data_handler import DataSimulator
from model_compra_comigo.data_handler import DataHandler
from numpy import arange
# Out:
# 2023-07-05 00:13:05.453414: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-05 00:13:05.570931: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-05 00:13:05.571946: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-05 00:13:06.376006: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
data_simulator = DataSimulator()
data_handler = DataHandler()

# %% [markdown]
# ## Slope

# %%
disable_trend: bool = False
disable_seasonality: bool = True
disable_noise: bool = True
disable_autocorrelation: bool = True
return_parameters: bool = False

# %%
time_range = 365*3
time = arange(time_range)
slope = 0.3

series = data_simulator.generate(
    time_range = time_range,
    trend_slope = slope,
    disable_trend = disable_trend,
    disable_seasonality = disable_seasonality,
    disable_noise = disable_noise,
    disable_autocorrelation = disable_autocorrelation,
    return_parameters=return_parameters
)

# %%
data_handler.plot_series(time=time, series=series, labels=[f'Slope={slope}'])
# Out:
# {"levelname": "WARNING", "asctime": "2023-07-05 00:13:07,782", "filename": "legend.py", "funcName": "_parse_legend_args", "lineno": 1323, "message": "No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument."}
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x800>

# %% [markdown]
# ## Seasonality

# %%
disable_trend: bool = True
disable_seasonality: bool = False
disable_noise: bool = True
disable_autocorrelation: bool = True
return_parameters: bool = False

# %%
time = arange(time_range)
time_range = 365*3
period = 365
amplitude = 40.
phase= 0.
time_threshold= 0.4
ncos = 2
nexp = 3

series = data_simulator.generate(
    time_range = time_range,
    seasonality_period = period,
    seasonality_amplitude = amplitude,
    seasonality_phase = phase,
    seasonality_time_threshold = time_threshold,
    seasonality_ncos = ncos,
    seasonality_nexp = nexp,
    disable_trend = disable_trend,
    disable_seasonality = disable_seasonality,
    disable_noise = disable_noise,
    disable_autocorrelation = disable_autocorrelation,
    return_parameters=return_parameters
)

# %%
data_handler.plot_series(
    time=time,
    series=series,
    labels=[f"seasonality_period = {period}",
            f"seasonality_amplitude = {amplitude}",
            f"seasonality_phase = {phase}",
            f"seasonality_time_threshold = {time_threshold}",
            f"seasonality_ncos = {ncos}",
            f"seasonality_nexp = {nexp}"]
)
# Out:
# {"levelname": "WARNING", "asctime": "2023-07-05 00:13:07,908", "filename": "legend.py", "funcName": "_parse_legend_args", "lineno": 1323, "message": "No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument."}
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x800>

# %% [markdown]
# ## Noise

# %%
disable_trend: bool = True
disable_seasonality: bool = True
disable_noise: bool = False
disable_autocorrelation: bool = True
return_parameters: bool = False

# %%
time = arange(time_range)
time_range = 365*3
scaling_factor = 10.

series = data_simulator.generate(
    time_range = time_range,
    noise_scaling_factor = scaling_factor,
    disable_trend = disable_trend,
    disable_seasonality = disable_seasonality,
    disable_noise = disable_noise,
    disable_autocorrelation = disable_autocorrelation,
    return_parameters=return_parameters
)

# %%
data_handler.plot_series(
    time=time,
    series=series,
    labels=[(f"seasonality_period = {period}\n"
             f"seasonality_amplitude = {amplitude}\n"
             f"seasonality_phase = {phase}\n"
             f"seasonality_time_threshold = {time_threshold}\n"
             f"seasonality_ncos = {ncos}\n"
             f"seasonality_nexp = {nexp}"
            )]
)
# Out:
# {"levelname": "WARNING", "asctime": "2023-07-05 00:13:08,044", "filename": "legend.py", "funcName": "_parse_legend_args", "lineno": 1323, "message": "No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument."}
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x800>

# %% [markdown]
# ## Autocorrelation

# %%
disable_trend: bool = True
disable_seasonality: bool = True
disable_noise: bool = True
disable_autocorrelation: bool = False
return_parameters: bool = False

# %%
time = arange(time_range)
time_range = 365*3
period = 365
amplitude = 100.
phi = 0.8

series = data_simulator.generate(
    time_range = time_range,
    autocorrelation_amplitude = amplitude,
    autocorrelation_phi = phi,
    disable_trend = disable_trend,
    disable_seasonality = disable_seasonality,
    disable_noise = disable_noise,
    disable_autocorrelation = disable_autocorrelation,
    return_parameters=return_parameters
)

# %%
data_handler.plot_series(
    time=time,
    series=series,
    labels=[f"autocorrelation_amplitude = {amplitude}",]
)
# Out:
# {"levelname": "WARNING", "asctime": "2023-07-05 00:13:08,158", "filename": "legend.py", "funcName": "_parse_legend_args", "lineno": 1323, "message": "No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument."}
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x800>

# %% [markdown]
# ## Generate a Dataset

# %%
time = arange(time_range)
time_range = 365*3
trend_slope = 0.3
seasonality_period = 365
seasonality_amplitude = 40.
seasonality_phase= 0.
seasonality_time_threshold= 0.4
seasonality_ncos = 2
seasonality_nexp = 3
noise_scaling_factor = 10.
autocorrelation_amplitude = 10.

series, parameters = data_simulator.generate(
    time_range = time_range,
    trend_slope = trend_slope,
    seasonality_period = seasonality_period,
    seasonality_amplitude = seasonality_amplitude,
    seasonality_phase = seasonality_phase,
    seasonality_time_threshold = seasonality_time_threshold,
    seasonality_ncos = seasonality_ncos,
    seasonality_nexp = seasonality_nexp,
    noise_scaling_factor = noise_scaling_factor,
    autocorrelation_amplitude = autocorrelation_amplitude
)

labels=[(f"trend_slope = {parameters['trend_slope']}\n"
         f"seasonality_period = {parameters['seasonality_period']}\n"
         f"seasonality_amplitude = {parameters['seasonality_amplitude']}\n"
         f"seasonality_phase = {parameters['seasonality_phase']}\n"
         f"seasonality_time_threshold = {parameters['seasonality_time_threshold']}\n"
         f"seasonality_ncos = {parameters['seasonality_ncos']}\n"
         f"seasonality_nexp = {parameters['seasonality_nexp']}\n"
         f"noise_scaling_factor = {parameters['noise_scaling_factor']}\n"
         f"autocorrelation_amplitude = {parameters['autocorrelation_amplitude']}\n"
         f"autocorrelation_phi = {parameters['autocorrelation_phi']}"
        )]

data_handler.plot_series(
    time=time,
    series=series,
    labels=labels
)
# Out:
# {"levelname": "WARNING", "asctime": "2023-07-05 00:13:08,264", "filename": "legend.py", "funcName": "_parse_legend_args", "lineno": 1323, "message": "No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument."}
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x800>

# %% [markdown]
# ## Generate a Dataset

# %%
time = arange(time_range)
time_range = 365*3

series, parameters = data_simulator.generate(
    time_range = time_range,
)

labels=[(f"trend_slope = {parameters['trend_slope']}\n"
         f"seasonality_period = {parameters['seasonality_period']}\n"
         f"seasonality_amplitude = {parameters['seasonality_amplitude']}\n"
         f"seasonality_phase = {parameters['seasonality_phase']}\n"
         f"seasonality_time_threshold = {parameters['seasonality_time_threshold']}\n"
         f"seasonality_ncos = {parameters['seasonality_ncos']}\n"
         f"seasonality_nexp = {parameters['seasonality_nexp']}\n"
         f"noise_scaling_factor = {parameters['noise_scaling_factor']}\n"
         f"autocorrelation_amplitude = {parameters['autocorrelation_amplitude']}\n"
         f"autocorrelation_phi = {parameters['autocorrelation_phi']}"
        )]

data_handler.plot_series(
    time=time,
    series=series,
    labels=labels
)
# Out:
# {"levelname": "WARNING", "asctime": "2023-07-05 00:13:08,374", "filename": "legend.py", "funcName": "_parse_legend_args", "lineno": 1323, "message": "No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument."}
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x800>
